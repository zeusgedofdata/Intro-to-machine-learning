# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import ipywidgets as widgets
import math
from random import randint

# %% [markdown]
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/00cb9b2c9b866378626bcfa45c86a6de2f2b2e40)

# %%
#Simulate a distribution. 
mu, sigma = 0, 10# mean and standard deviation
s = np.random.normal(mu, sigma, 10000)
count, bins, ignored = plt.hist(s, 30, density=True)

mean = np.sum(s)/len(s)

std = math.sqrt(sum([(x-mu)**2 for x in s])/len(s))
print(str(mean) + " VS " + str(mu))
print(str(std) + " VS " + str(sigma))
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
# Out:
# 0.17652076222290292 VS 0
# 10.084417279229472 VS 10
